# %% [markdown]
# ## Lab 3
# ### Part 2: Dealing with overfitting

# %% [markdown]
# Today we work with [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist) (*hint: it is available in `torchvision`*).
#
# Your goal for today:
# 1. Train a FC (fully-connected) network that achieves >= 0.885 test accuracy.
# 2. Cause considerable overfitting by modifying the network (e.g. increasing the number of network parameters and/or layers) and demonstrate in in the appropriate way (e.g. plot loss and accurasy on train and validation set w.r.t. network complexity).
# 3. Try to deal with overfitting (at least partially) by using regularization techniques (Dropout/Batchnorm/...) and demonstrate the results.
#
# __Please, write a small report describing your ideas, tries and achieved results in the end of this file.__
#
# *Note*: Tasks 2 and 3 are interrelated, in task 3 your goal is to make the network from task 2 less prone to overfitting. Task 1 is independent from 2 and 3.
#
# *Note 2*: We recomment to use Google Colab or other machine with GPU acceleration.

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torchsummary
from IPython.display import clear_output
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import os


device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
# Technical function
def mkdir(path):
    if not os.path.exists(root_path):
        os.mkdir(root_path)
        print('Directory', path, 'is created!')
    else:
        print('Directory', path, 'already exists!')
        
root_path = 'fmnist'
mkdir(root_path)
# Out:
# Directory fmnist already exists!

# %%
download = True
train_transform = transforms.ToTensor()
test_transform = transforms.ToTensor()
transforms.Compose((transforms.ToTensor()))


fmnist_dataset_train = torchvision.datasets.FashionMNIST(root_path, 
                                                        train=True, 
                                                        transform=train_transform,
                                                        target_transform=None,
                                                        download=download)
fmnist_dataset_test = torchvision.datasets.FashionMNIST(root_path, 
                                                       train=False, 
                                                       transform=test_transform,
                                                       target_transform=None,
                                                       download=download)

# %%
train_loader = torch.utils.data.DataLoader(fmnist_dataset_train, 
                                           batch_size=128,
                                           shuffle=True,
                                           num_workers=0)

test_loader = torch.utils.data.DataLoader(fmnist_dataset_test,
                                          batch_size=256,
                                          shuffle=False,
                                          num_workers=0)

# %%
len(fmnist_dataset_test)
# Out:
# 10000

# %%
for img, label in train_loader:
    print(img.shape)
#     print(img)
    print(label.shape)
    print(label.size(0))
    break
# Out:
# torch.Size([128, 1, 28, 28])
# torch.Size([128])
# 128

# %% [markdown]
# ### Task 1
# Train a network that achieves $\geq 0.885$ test accuracy. It's fine to use only Linear (`nn.Linear`) layers and activations/dropout/batchnorm. Convolutional layers might be a great use, but we will meet them a bit later.

# %%
class TinyNeuralNetwork(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, 500),
            nn.BatchNorm1d(500, eps=3e-4),
            nn.ReLU(),
            nn.Linear(500, 300),
            nn.ReLU(),
            nn.Dropout(p=0.2,inplace = False),
            nn.Linear(300, 100),
            nn.ReLU(),
            nn.Linear(100, num_classes)
        )
        
    def forward(self, inp):       
        out = self.model(inp)
        return out

# %%
torchsummary.summary(TinyNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                  [-1, 500]         392,500
#        BatchNorm1d-3                  [-1, 500]           1,000
#               ReLU-4                  [-1, 500]               0
#             Linear-5                  [-1, 300]         150,300
#               ReLU-6                  [-1, 300]               0
#            Dropout-7                  [-1, 300]               0
#             Linear-8                  [-1, 100]          30,100
#               ReLU-9                  [-1, 100]               0
#            Linear-10                   [-1, 10]           1,010
# ================================================================
# Total params: 574,910
# Trainable params: 574,910
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 2.19
# Estimated Total Size (MB): 2.22
# ----------------------------------------------------------------

# %% [markdown]
# Your experiments come here:

# %%
from torch.optim import Adam
import time


model = TinyNeuralNetwork().to(device)
opt = Adam(model.parameters(), lr=1e-3)
loss_func = nn.CrossEntropyLoss()


def train_model(model, train_loader, val_loader, loss_fn, opt, n_epochs: int):
    '''
    model: нейросеть для обучения,
    train_loader, val_loader: загрузчики данных
    loss_fn: целевая метрика (которую будем оптимизировать)
    opt: оптимизатор (обновляет веса нейросети)
    n_epochs: кол-во эпох, полных проходов датасета
    '''
    train_loss = []
    val_loss = []
    val_accuracy = []
    
    for epoch in range(n_epochs):
        ep_train_loss = []
        ep_val_loss = []
        ep_val_accuracy = []
        start_time = time.time()

        model.train(True)
        for X_batch, y_batch in train_loader:
                opt.zero_grad()
                
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                
                predictions = model(X_batch)
                loss = loss_fn(predictions, y_batch)
                loss.backward()
                opt.step()
                
                ep_train_loss.append(loss.item())
            

        model.train(False)
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                
                predictions = model(X_batch)
                loss = loss_fn(predictions, y_batch)

                ep_val_loss.append(loss.item())
                y_pred = predictions.max(1)[1].data 
                ep_val_accuracy.append(np.mean((y_batch.cpu() == y_pred.cpu()).numpy() ))

        # print the results for this epoch:
        print(f'Epoch {epoch + 1} of {n_epochs} took {time.time() - start_time:.3f}s')

        train_loss.append(np.mean(ep_train_loss))
        val_loss.append(np.mean(ep_val_loss))
        val_accuracy.append(np.mean(ep_val_accuracy))
        
        print(f"\t  training loss: {train_loss[-1]:.6f}")
        print(f"\tvalidation loss: {val_loss[-1]:.6f}")
        print(f"\tvalidation accuracy: {val_accuracy[-1]:.3f}")

    return train_loss, val_loss, val_accuracy

# %%
n_epochs = 30

train_loss, val_loss, val_accuracy = train_model(model, 
                                                 train_loader, 
                                                 test_loader, 
                                                 loss_func, 
                                                 opt, 
                                                 n_epochs)
# Out:
# Epoch 1 of 30 took 14.259s
# 	  training loss: 0.475558
# 	validation loss: 0.419435
# 	validation accuracy: 0.845
# Epoch 2 of 30 took 13.589s
# 	  training loss: 0.344002
# 	validation loss: 0.388334
# 	validation accuracy: 0.856
# Epoch 3 of 30 took 13.179s
# 	  training loss: 0.311611
# 	validation loss: 0.433727
# 	validation accuracy: 0.853
# Epoch 4 of 30 took 13.794s
# 	  training loss: 0.280991
# 	validation loss: 0.338540
# 	validation accuracy: 0.881
# Epoch 5 of 30 took 14.223s
# 	  training loss: 0.264396
# 	validation loss: 0.351248
# 	validation accuracy: 0.871
# Epoch 6 of 30 took 13.585s
# 	  training loss: 0.244276
# 	validation loss: 0.312831
# 	validation accuracy: 0.890
# Epoch 7 of 30 took 14.193s
# 	  training loss: 0.230127
# 	validation loss: 0.330485
# 	validation accuracy: 0.883
# Epoch 8 of 30 took 13.724s
# 	  training loss: 0.216248
# 	validation loss: 0.311852
# 	validation accuracy: 0.895
# Epoch 9 of 30 took 13.686s
# 	  training loss: 0.203051
# 	validation loss: 0.338931
# 	validation accuracy: 0.887
# Epoch 10 of 30 took 14.449s
# 	  training loss: 0.190806
# 	validation loss: 0.317056
# 	validation accuracy: 0.893
# Epoch 11 of 30 took 14.757s
# 	  training loss: 0.186076
# 	validation loss: 0.334316
# 	validation accuracy: 0.888
# Epoch 12 of 30 took 14.829s
# 	  training loss: 0.172866
# 	validation loss: 0.335958
# 	validation accuracy: 0.892
# Epoch 13 of 30 took 14.705s
# 	  training loss: 0.160893
# 	validation loss: 0.360014
# 	validation accuracy: 0.887
# Epoch 14 of 30 took 14.685s
# 	  training loss: 0.153368
# 	validation loss: 0.361566
# 	validation accuracy: 0.888
# Epoch 15 of 30 took 14.931s
# 	  training loss: 0.144538
# 	validation loss: 0.393298
# 	validation accuracy: 0.882
# Epoch 16 of 30 took 11.734s
# 	  training loss: 0.137170
# 	validation loss: 0.368021
# 	validation accuracy: 0.892
# Epoch 17 of 30 took 11.788s
# 	  training loss: 0.130561
# 	validation loss: 0.361421
# 	validation accuracy: 0.896
# Epoch 18 of 30 took 12.088s
# 	  training loss: 0.125539
# 	validation loss: 0.390973
# 	validation accuracy: 0.891
# Epoch 19 of 30 took 11.457s
# 	  training loss: 0.117918
# 	validation loss: 0.408473
# 	validation accuracy: 0.891
# Epoch 20 of 30 took 11.345s
# 	  training loss: 0.110701
# 	validation loss: 0.405034
# 	validation accuracy: 0.895
# Epoch 21 of 30 took 11.885s
# 	  training loss: 0.105477
# 	validation loss: 0.432044
# 	validation accuracy: 0.891
# Epoch 22 of 30 took 11.784s
# 	  training loss: 0.105000
# 	validation loss: 0.386508
# 	validation accuracy: 0.898
# Epoch 23 of 30 took 11.800s
# 	  training loss: 0.094685
# 	validation loss: 0.467300
# 	validation accuracy: 0.887
# Epoch 24 of 30 took 11.860s
# 	  training loss: 0.095478
# 	validation loss: 0.429043
# 	validation accuracy: 0.896
# Epoch 25 of 30 took 11.795s
# 	  training loss: 0.089979
# 	validation loss: 0.506856
# 	validation accuracy: 0.883
# Epoch 26 of 30 took 11.891s
# 	  training loss: 0.084972
# 	validation loss: 0.482427
# 	validation accuracy: 0.887
# Epoch 27 of 30 took 11.924s
# 	  training loss: 0.083506
# 	validation loss: 0.468346
# 	validation accuracy: 0.893
# Epoch 28 of 30 took 11.781s
# 	  training loss: 0.081681
# 	validation loss: 0.537829
# 	validation accuracy: 0.883
# Epoch 29 of 30 took 12.001s
# 	  training loss: 0.078908
# 	validation loss: 0.470781
# 	validation accuracy: 0.897
# Epoch 30 of 30 took 13.378s
# 	  training loss: 0.074336
# 	validation loss: 0.517003
# 	validation accuracy: 0.892

# %%
def plot_train_process(train_loss, val_loss, val_accuracy):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    axes[0].set_title('Loss')
    axes[0].plot(train_loss, label='train')
    axes[0].plot(val_loss, label='validation')
    axes[0].legend()

    axes[1].set_title('Validation accuracy')
    axes[1].plot(val_accuracy)

# %%
plot_train_process(train_loss, val_loss, val_accuracy)

# %% [markdown]
# **Вывод:** мы достигли требуемой оценки 0.885.

# %% [markdown]
# ### Task 2: Overfit it.
# Build a network that will overfit to this dataset. Demonstrate the overfitting in the appropriate way (e.g. plot loss and accurasy on train and test set w.r.t. network complexity).
#
# *Note:* you also might decrease the size of `train` dataset to enforce the overfitting and speed up the computations.

# %% [markdown]
# Для того чтобы добиться переобучение сделаем много больших слоев

# %%
print(len(train_loader))

print(len(test_loader))
# Out:
# 469
# 40

# %%
class OverfittingNeuralNetwork(nn.Module):
    def __init__(self, input_shape = 28 * 28, num_classes = 10, input_channels = 1):
        
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, 1000),
            nn.Tanh(),
            nn.Linear(1000, 500),
            nn.Tanh(),
            nn.Linear(500, num_classes)
        )
        
    def forward(self, inp):       
        out = self.model(inp)
        return out

# %%
torchsummary.summary(OverfittingNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                 [-1, 1000]         785,000
#               Tanh-3                 [-1, 1000]               0
#             Linear-4                  [-1, 500]         500,500
#               Tanh-5                  [-1, 500]               0
#             Linear-6                   [-1, 10]           5,010
# ================================================================
# Total params: 1,290,510
# Trainable params: 1,290,510
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 4.92
# Estimated Total Size (MB): 4.95
# ----------------------------------------------------------------

# %%
model = OverfittingNeuralNetwork().to(device)
opt = Adam(model.parameters(), lr=1e-3)
loss_func = nn.CrossEntropyLoss()

n_epochs = 50

train_loss, val_loss, val_accuracy = train_model(model, 
                                                 train_loader, 
                                                 test_loader, 
                                                 loss_func, 
                                                 opt, 
                                                 n_epochs)
# Out:
# Epoch 1 of 50 took 12.218s
# 	  training loss: 0.495032
# 	validation loss: 0.424991
# 	validation accuracy: 0.846
# Epoch 2 of 50 took 12.572s
# 	  training loss: 0.380514
# 	validation loss: 0.382827
# 	validation accuracy: 0.862
# Epoch 3 of 50 took 11.372s
# 	  training loss: 0.338110
# 	validation loss: 0.373437
# 	validation accuracy: 0.863
# Epoch 4 of 50 took 12.757s
# 	  training loss: 0.317472
# 	validation loss: 0.373370
# 	validation accuracy: 0.862
# Epoch 5 of 50 took 13.354s
# 	  training loss: 0.297860
# 	validation loss: 0.351402
# 	validation accuracy: 0.871
# Epoch 6 of 50 took 11.659s
# 	  training loss: 0.286666
# 	validation loss: 0.341569
# 	validation accuracy: 0.878
# Epoch 7 of 50 took 11.907s
# 	  training loss: 0.276840
# 	validation loss: 0.337593
# 	validation accuracy: 0.879
# Epoch 8 of 50 took 11.809s
# 	  training loss: 0.263439
# 	validation loss: 0.321423
# 	validation accuracy: 0.886
# Epoch 9 of 50 took 12.320s
# 	  training loss: 0.253248
# 	validation loss: 0.333926
# 	validation accuracy: 0.880
# Epoch 10 of 50 took 12.314s
# 	  training loss: 0.246086
# 	validation loss: 0.327911
# 	validation accuracy: 0.879
# Epoch 11 of 50 took 11.932s
# 	  training loss: 0.243260
# 	validation loss: 0.331019
# 	validation accuracy: 0.879
# Epoch 12 of 50 took 11.833s
# 	  training loss: 0.232056
# 	validation loss: 0.350859
# 	validation accuracy: 0.875
# Epoch 13 of 50 took 11.964s
# 	  training loss: 0.233009
# 	validation loss: 0.338945
# 	validation accuracy: 0.882
# Epoch 14 of 50 took 11.697s
# 	  training loss: 0.220536
# 	validation loss: 0.340297
# 	validation accuracy: 0.879
# Epoch 15 of 50 took 12.753s
# 	  training loss: 0.218622
# 	validation loss: 0.340261
# 	validation accuracy: 0.880
# Epoch 16 of 50 took 11.908s
# 	  training loss: 0.211687
# 	validation loss: 0.338563
# 	validation accuracy: 0.882
# Epoch 17 of 50 took 12.486s
# 	  training loss: 0.205533
# 	validation loss: 0.346946
# 	validation accuracy: 0.881
# Epoch 18 of 50 took 12.696s
# 	  training loss: 0.203871
# 	validation loss: 0.324338
# 	validation accuracy: 0.887
# Epoch 19 of 50 took 12.578s
# 	  training loss: 0.195378
# 	validation loss: 0.326269
# 	validation accuracy: 0.889
# Epoch 20 of 50 took 13.184s
# 	  training loss: 0.191016
# 	validation loss: 0.337073
# 	validation accuracy: 0.881
# Epoch 21 of 50 took 12.426s
# 	  training loss: 0.187360
# 	validation loss: 0.326565
# 	validation accuracy: 0.892
# Epoch 22 of 50 took 13.576s
# 	  training loss: 0.187296
# 	validation loss: 0.329492
# 	validation accuracy: 0.888
# Epoch 23 of 50 took 12.348s
# 	  training loss: 0.190804
# 	validation loss: 0.345977
# 	validation accuracy: 0.879
# Epoch 24 of 50 took 11.484s
# 	  training loss: 0.176940
# 	validation loss: 0.349370
# 	validation accuracy: 0.886
# Epoch 25 of 50 took 11.939s
# 	  training loss: 0.177378
# 	validation loss: 0.343685
# 	validation accuracy: 0.883
# Epoch 26 of 50 took 12.591s
# 	  training loss: 0.174624
# 	validation loss: 0.355704
# 	validation accuracy: 0.883
# Epoch 27 of 50 took 11.677s
# 	  training loss: 0.179128
# 	validation loss: 0.357533
# 	validation accuracy: 0.880
# Epoch 28 of 50 took 13.022s
# 	  training loss: 0.173487
# 	validation loss: 0.359150
# 	validation accuracy: 0.883
# Epoch 29 of 50 took 12.903s
# 	  training loss: 0.170866
# 	validation loss: 0.371984
# 	validation accuracy: 0.881
# Epoch 30 of 50 took 12.139s
# 	  training loss: 0.169057
# 	validation loss: 0.359480
# 	validation accuracy: 0.884
# Epoch 31 of 50 took 12.381s
# 	  training loss: 0.162874
# 	validation loss: 0.346906
# 	validation accuracy: 0.887
# Epoch 32 of 50 took 14.568s
# 	  training loss: 0.159628
# 	validation loss: 0.379239
# 	validation accuracy: 0.876
# Epoch 33 of 50 took 12.430s
# 	  training loss: 0.158457
# 	validation loss: 0.381516
# 	validation accuracy: 0.878
# Epoch 34 of 50 took 14.362s
# 	  training loss: 0.155534
# 	validation loss: 0.360352
# 	validation accuracy: 0.886
# Epoch 35 of 50 took 12.445s
# 	  training loss: 0.158950
# 	validation loss: 0.369054
# 	validation accuracy: 0.883
# Epoch 36 of 50 took 13.259s
# 	  training loss: 0.153373
# 	validation loss: 0.355055
# 	validation accuracy: 0.885
# Epoch 37 of 50 took 12.689s
# 	  training loss: 0.151732
# 	validation loss: 0.376919
# 	validation accuracy: 0.882
# Epoch 38 of 50 took 12.015s
# 	  training loss: 0.155615
# 	validation loss: 0.351191
# 	validation accuracy: 0.888
# Epoch 39 of 50 took 12.917s
# 	  training loss: 0.153612
# 	validation loss: 0.355749
# 	validation accuracy: 0.892
# Epoch 40 of 50 took 11.992s
# 	  training loss: 0.151938
# 	validation loss: 0.352908
# 	validation accuracy: 0.889
# Epoch 41 of 50 took 12.668s
# 	  training loss: 0.152816
# 	validation loss: 0.364337
# 	validation accuracy: 0.887
# Epoch 42 of 50 took 12.887s
# 	  training loss: 0.144314
# 	validation loss: 0.387399
# 	validation accuracy: 0.880
# Epoch 43 of 50 took 12.319s
# 	  training loss: 0.143114
# 	validation loss: 0.388605
# 	validation accuracy: 0.880
# Epoch 44 of 50 took 11.378s
# 	  training loss: 0.146571
# 	validation loss: 0.369965
# 	validation accuracy: 0.891
# Epoch 45 of 50 took 11.087s
# 	  training loss: 0.139727
# 	validation loss: 0.378041
# 	validation accuracy: 0.890
# Epoch 46 of 50 took 11.441s
# 	  training loss: 0.148285
# 	validation loss: 0.382611
# 	validation accuracy: 0.888
# Epoch 47 of 50 took 11.186s
# 	  training loss: 0.144367
# 	validation loss: 0.386980
# 	validation accuracy: 0.884
# Epoch 48 of 50 took 11.340s
# 	  training loss: 0.142870
# 	validation loss: 0.369934
# 	validation accuracy: 0.887
# Epoch 49 of 50 took 12.111s
# 	  training loss: 0.143999
# 	validation loss: 0.393671
# 	validation accuracy: 0.887
# Epoch 50 of 50 took 12.930s
# 	  training loss: 0.139484
# 	validation loss: 0.369652
# 	validation accuracy: 0.888

# %%
plot_train_process(train_loss, val_loss, val_accuracy)

# %% [markdown]
# **Вывод:** мы смогли переобучиться.

# %% [markdown]
# ### Task 3: Fix it.
# Fix the overfitted network from the previous step (at least partially) by using regularization techniques (Dropout/Batchnorm/...) and demonstrate the results.

# %%
class FixedNeuralNetwork(nn.Module):
    def __init__(self, input_shape = 28 * 28, num_classes = 10, input_channels = 1):
        
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, 1000),
            nn.Tanh(),
            nn.Dropout(p = .40, inplace= False),
            nn.Linear(1000, 500),
            nn.Tanh(),
            nn.BatchNorm1d(500, eps=3e-5),
            nn.Linear(500, num_classes)
        )
        
    def forward(self, inp):       
        out = self.model(inp)
        return out

# %%
torchsummary.summary(FixedNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                 [-1, 1000]         785,000
#               Tanh-3                 [-1, 1000]               0
#            Dropout-4                 [-1, 1000]               0
#             Linear-5                  [-1, 500]         500,500
#               Tanh-6                  [-1, 500]               0
#        BatchNorm1d-7                  [-1, 500]           1,000
#             Linear-8                   [-1, 10]           5,010
# ================================================================
# Total params: 1,291,510
# Trainable params: 1,291,510
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.04
# Params size (MB): 4.93
# Estimated Total Size (MB): 4.97
# ----------------------------------------------------------------

# %%
model = FixedNeuralNetwork().to(device)
opt = Adam(model.parameters(), lr=1e-3)
loss_func = nn.CrossEntropyLoss()

n_epochs = 50

train_loss, val_loss, val_accuracy = train_model(model, 
                                                 train_loader, 
                                                 test_loader, 
                                                 loss_func, 
                                                 opt, 
                                                 n_epochs)
# Out:
# Epoch 1 of 50 took 16.035s
# 	  training loss: 0.506919
# 	validation loss: 0.450098
# 	validation accuracy: 0.832
# Epoch 2 of 50 took 16.431s
# 	  training loss: 0.407730
# 	validation loss: 0.467418
# 	validation accuracy: 0.828
# Epoch 3 of 50 took 16.437s
# 	  training loss: 0.375683
# 	validation loss: 0.398580
# 	validation accuracy: 0.854
# Epoch 4 of 50 took 16.421s
# 	  training loss: 0.352857
# 	validation loss: 0.377570
# 	validation accuracy: 0.863
# Epoch 5 of 50 took 16.718s
# 	  training loss: 0.336425
# 	validation loss: 0.353084
# 	validation accuracy: 0.870
# Epoch 6 of 50 took 16.530s
# 	  training loss: 0.328839
# 	validation loss: 0.360335
# 	validation accuracy: 0.862
# Epoch 7 of 50 took 16.431s
# 	  training loss: 0.319919
# 	validation loss: 0.365955
# 	validation accuracy: 0.862
# Epoch 8 of 50 took 16.400s
# 	  training loss: 0.311301
# 	validation loss: 0.347311
# 	validation accuracy: 0.873
# Epoch 9 of 50 took 16.483s
# 	  training loss: 0.308418
# 	validation loss: 0.340646
# 	validation accuracy: 0.877
# Epoch 10 of 50 took 16.509s
# 	  training loss: 0.300770
# 	validation loss: 0.354495
# 	validation accuracy: 0.874
# Epoch 11 of 50 took 16.395s
# 	  training loss: 0.299315
# 	validation loss: 0.343735
# 	validation accuracy: 0.876
# Epoch 12 of 50 took 16.522s
# 	  training loss: 0.293844
# 	validation loss: 0.342634
# 	validation accuracy: 0.875
# Epoch 13 of 50 took 16.450s
# 	  training loss: 0.292073
# 	validation loss: 0.334112
# 	validation accuracy: 0.880
# Epoch 14 of 50 took 16.485s
# 	  training loss: 0.289360
# 	validation loss: 0.354774
# 	validation accuracy: 0.875
# Epoch 15 of 50 took 16.415s
# 	  training loss: 0.285415
# 	validation loss: 0.339572
# 	validation accuracy: 0.877
# Epoch 16 of 50 took 16.460s
# 	  training loss: 0.281680
# 	validation loss: 0.327612
# 	validation accuracy: 0.878
# Epoch 17 of 50 took 16.427s
# 	  training loss: 0.280455
# 	validation loss: 0.327745
# 	validation accuracy: 0.881
# Epoch 18 of 50 took 16.430s
# 	  training loss: 0.275920
# 	validation loss: 0.346061
# 	validation accuracy: 0.878
# Epoch 19 of 50 took 16.439s
# 	  training loss: 0.277753
# 	validation loss: 0.331770
# 	validation accuracy: 0.881
# Epoch 20 of 50 took 16.668s
# 	  training loss: 0.276037
# 	validation loss: 0.335725
# 	validation accuracy: 0.881
# Epoch 21 of 50 took 16.510s
# 	  training loss: 0.274958
# 	validation loss: 0.329440
# 	validation accuracy: 0.879
# Epoch 22 of 50 took 16.497s
# 	  training loss: 0.270748
# 	validation loss: 0.329685
# 	validation accuracy: 0.880
# Epoch 23 of 50 took 16.499s
# 	  training loss: 0.270596
# 	validation loss: 0.328839
# 	validation accuracy: 0.883
# Epoch 24 of 50 took 17.393s
# 	  training loss: 0.271850
# 	validation loss: 0.340031
# 	validation accuracy: 0.882
# Epoch 25 of 50 took 18.929s
# 	  training loss: 0.269635
# 	validation loss: 0.330180
# 	validation accuracy: 0.880
# Epoch 26 of 50 took 16.547s
# 	  training loss: 0.265870
# 	validation loss: 0.331624
# 	validation accuracy: 0.882
# Epoch 27 of 50 took 16.516s
# 	  training loss: 0.262449
# 	validation loss: 0.332226
# 	validation accuracy: 0.882
# Epoch 28 of 50 took 16.535s
# 	  training loss: 0.260673
# 	validation loss: 0.329787
# 	validation accuracy: 0.880
# Epoch 29 of 50 took 16.791s
# 	  training loss: 0.257323
# 	validation loss: 0.331141
# 	validation accuracy: 0.881
# Epoch 30 of 50 took 18.088s
# 	  training loss: 0.258877
# 	validation loss: 0.336690
# 	validation accuracy: 0.879
# Epoch 31 of 50 took 19.138s
# 	  training loss: 0.258177
# 	validation loss: 0.312036
# 	validation accuracy: 0.885
# Epoch 32 of 50 took 18.454s
# 	  training loss: 0.254336
# 	validation loss: 0.324425
# 	validation accuracy: 0.884
# Epoch 33 of 50 took 18.781s
# 	  training loss: 0.253866
# 	validation loss: 0.325734
# 	validation accuracy: 0.884
# Epoch 34 of 50 took 18.437s
# 	  training loss: 0.252924
# 	validation loss: 0.325175
# 	validation accuracy: 0.884
# Epoch 35 of 50 took 16.827s
# 	  training loss: 0.252944
# 	validation loss: 0.320267
# 	validation accuracy: 0.887
# Epoch 36 of 50 took 16.503s
# 	  training loss: 0.248313
# 	validation loss: 0.332457
# 	validation accuracy: 0.880
# Epoch 37 of 50 took 17.647s
# 	  training loss: 0.250970
# 	validation loss: 0.322507
# 	validation accuracy: 0.885
# Epoch 38 of 50 took 20.182s
# 	  training loss: 0.252890
# 	validation loss: 0.331978
# 	validation accuracy: 0.883
# Epoch 39 of 50 took 17.856s
# 	  training loss: 0.249742
# 	validation loss: 0.323540
# 	validation accuracy: 0.885
# Epoch 40 of 50 took 17.486s
# 	  training loss: 0.250014
# 	validation loss: 0.326347
# 	validation accuracy: 0.882
# Epoch 41 of 50 took 17.686s
# 	  training loss: 0.249208
# 	validation loss: 0.328037
# 	validation accuracy: 0.886
# Epoch 42 of 50 took 17.661s
# 	  training loss: 0.246053
# 	validation loss: 0.320786
# 	validation accuracy: 0.887
# Epoch 43 of 50 took 17.761s
# 	  training loss: 0.247411
# 	validation loss: 0.321015
# 	validation accuracy: 0.887
# Epoch 44 of 50 took 17.767s
# 	  training loss: 0.244183
# 	validation loss: 0.326700
# 	validation accuracy: 0.887
# Epoch 45 of 50 took 17.727s
# 	  training loss: 0.242127
# 	validation loss: 0.317476
# 	validation accuracy: 0.887
# Epoch 46 of 50 took 17.958s
# 	  training loss: 0.242716
# 	validation loss: 0.317317
# 	validation accuracy: 0.888
# Epoch 47 of 50 took 18.188s
# 	  training loss: 0.242622
# 	validation loss: 0.316073
# 	validation accuracy: 0.887
# Epoch 48 of 50 took 17.546s
# 	  training loss: 0.244066
# 	validation loss: 0.334864
# 	validation accuracy: 0.885
# Epoch 49 of 50 took 17.183s
# 	  training loss: 0.239832
# 	validation loss: 0.319172
# 	validation accuracy: 0.889
# Epoch 50 of 50 took 18.019s
# 	  training loss: 0.242030
# 	validation loss: 0.317072
# 	validation accuracy: 0.888

# %%
plot_train_process(train_loss, val_loss, val_accuracy)

# %% [markdown]
# ### Conclusions:
# _Write down small report with your conclusions and your ideas._

# %% [markdown]
# Нейронки очень легко переобучиться, и для того чтобы избежать это стоит делать следующее:
# - Нормализировать данные (**nn.BatchNorm1d**).
# - Использовать **Dropout**.
# - Использовать _правильный_ оптимайзер.
# - Выбирать правильную стратегию кросс-валидации.
# - Контролировать количество слоев и их размер.
# - Правильно подбирать количество эпох.
#
# Для обучения нейронок очень полезно иметь GPU.
