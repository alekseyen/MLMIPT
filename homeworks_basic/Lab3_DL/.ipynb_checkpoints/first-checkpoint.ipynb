# %% [markdown]
# ## Lab 3
# ### Part 2: Dealing with overfitting

# %% [markdown]
# Today we work with [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist) (*hint: it is available in `torchvision`*).
#
# Your goal for today:
# 1. Train a FC (fully-connected) network that achieves >= 0.885 test accuracy.
# 2. Cause considerable overfitting by modifying the network (e.g. increasing the number of network parameters and/or layers) and demonstrate in in the appropriate way (e.g. plot loss and accurasy on train and validation set w.r.t. network complexity).
# 3. Try to deal with overfitting (at least partially) by using regularization techniques (Dropout/Batchnorm/...) and demonstrate the results.
#
# __Please, write a small report describing your ideas, tries and achieved results in the end of this file.__
#
# *Note*: Tasks 2 and 3 are interrelated, in task 3 your goal is to make the network from task 2 less prone to overfitting. Task 1 is independent from 2 and 3.
#
# *Note 2*: We recomment to use Google Colab or other machine with GPU acceleration.

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torchsummary
from IPython.display import clear_output
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import os


device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
# Technical function
def mkdir(path):
    if not os.path.exists(root_path):
        os.mkdir(root_path)
        print('Directory', path, 'is created!')
    else:
        print('Directory', path, 'already exists!')
        
root_path = 'fmnist'
mkdir(root_path)
# Out:
# Directory fmnist already exists!

# %%
download = True
train_transform = transforms.ToTensor()
test_transform = transforms.ToTensor()
transforms.Compose((transforms.ToTensor()))


fmnist_dataset_train = torchvision.datasets.FashionMNIST(root_path, 
                                                        train=True, 
                                                        transform=train_transform,
                                                        target_transform=None,
                                                        download=download)
fmnist_dataset_test = torchvision.datasets.FashionMNIST(root_path, 
                                                       train=False, 
                                                       transform=test_transform,
                                                       target_transform=None,
                                                       download=download)

# %%
train_loader = torch.utils.data.DataLoader(fmnist_dataset_train, 
                                           batch_size=128,
                                           shuffle=True,
                                           num_workers=0)

test_loader = torch.utils.data.DataLoader(fmnist_dataset_test,
                                          batch_size=256,
                                          shuffle=False,
                                          num_workers=0)

# %%
len(fmnist_dataset_test)
# Out:
# 10000

# %%
for img, label in train_loader:
    print(img.shape)
#     print(img)
    print(label.shape)
    print(label.size(0))
    break
# Out:
# torch.Size([128, 1, 28, 28])
# torch.Size([128])
# 128

# %% [markdown]
# ### Task 1
# Train a network that achieves $\geq 0.885$ test accuracy. It's fine to use only Linear (`nn.Linear`) layers and activations/dropout/batchnorm. Convolutional layers might be a great use, but we will meet them a bit later.

# %%
# просто вставлю чтобы помнить что так можно делать
class Flatten():
    def __call__(self, pic):
        return pic.flatten()

    def __repr__(self):
        return self.__class__.__name__ + '()'

# %%
class TinyNeuralNetwork(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, 500),
            nn.ReLU(),
            nn.Linear(500, 300),
            nn.ReLU(),
            nn.Dropout(p=0.6,inplace = False),
            nn.Linear(300, 100),
            nn.ReLU(),
            nn.Linear(100, num_classes)
        )
        
    def forward(self, inp):       
        out = self.model(inp)
        return out

# %%
torchsummary.summary(TinyNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                  [-1, 500]         392,500
#               ReLU-3                  [-1, 500]               0
#             Linear-4                  [-1, 300]         150,300
#               ReLU-5                  [-1, 300]               0
#            Dropout-6                  [-1, 300]               0
#             Linear-7                  [-1, 100]          30,100
#               ReLU-8                  [-1, 100]               0
#             Linear-9                   [-1, 10]           1,010
# ================================================================
# Total params: 573,910
# Trainable params: 573,910
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 2.19
# Estimated Total Size (MB): 2.21
# ----------------------------------------------------------------

# %% [markdown]
# Your experiments come here:

# %%
from torch.optim import Adam
import time


model = TinyNeuralNetwork().to(device)
opt = Adam(model.parameters(), lr=1e-3)
loss_func = nn.CrossEntropyLoss()


def train_model(model, train_loader, val_loader, loss_fn, opt, n_epochs: int):
    '''
    model: нейросеть для обучения,
    train_loader, val_loader: загрузчики данных
    loss_fn: целевая метрика (которую будем оптимизировать)
    opt: оптимизатор (обновляет веса нейросети)
    n_epochs: кол-во эпох, полных проходов датасета
    '''
    train_loss = []
    val_loss = []
    val_accuracy = []
    
    for epoch in range(n_epochs):
        ep_train_loss = []
        ep_val_loss = []
        ep_val_accuracy = []
        start_time = time.time()

        model.train(True) # enable dropout / batch_norm training behavior
        for X_batch, y_batch in train_loader:
                opt.zero_grad()
                
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                
                predictions = model(X_batch)
                loss = loss_fn(predictions, y_batch)
                loss.backward()
                opt.step()
                
                ep_train_loss.append(loss.item())
            

        model.train(False) # disable dropout / use averages for batch_norm
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                
                predictions = model(X_batch)
                loss = loss_fn(predictions, y_batch)

                ep_val_loss.append(loss.item())
                y_pred = predictions.max(1)[1].data 
                ep_val_accuracy.append(np.mean((y_batch.cpu() == y_pred.cpu()).numpy() ))

        # print the results for this epoch:
        print(f'Epoch {epoch + 1} of {n_epochs} took {time.time() - start_time:.3f}s')

        train_loss.append(np.mean(ep_train_loss))
        val_loss.append(np.mean(ep_val_loss))
        val_accuracy.append(np.mean(ep_val_accuracy))
        
        print(f"\t  training loss: {train_loss[-1]:.6f}")
        print(f"\tvalidation loss: {val_loss[-1]:.6f}")
        print(f"\tvalidation accuracy: {val_accuracy[-1]:.3f}")

    return train_loss, val_loss, val_accuracy

# %%
n_epochs = 30

train_loss, val_loss, val_accuracy = train_model(model, 
                                                 train_loader, 
                                                 test_loader, 
                                                 loss_func, 
                                                 opt, 
                                                 n_epochs)
# Out:
# Epoch 1 of 30 took 8.776s
# 	  training loss: 0.631537
# 	validation loss: 0.438187
# 	validation accuracy: 0.843
# Epoch 2 of 30 took 9.089s
# 	  training loss: 0.407865
# 	validation loss: 0.380853
# 	validation accuracy: 0.865
# Epoch 3 of 30 took 9.352s
# 	  training loss: 0.360017
# 	validation loss: 0.395217
# 	validation accuracy: 0.861
# Epoch 4 of 30 took 9.458s
# 	  training loss: 0.334690
# 	validation loss: 0.391665
# 	validation accuracy: 0.858
# Epoch 5 of 30 took 9.488s
# 	  training loss: 0.314667
# 	validation loss: 0.344285
# 	validation accuracy: 0.873
# Epoch 6 of 30 took 9.557s
# 	  training loss: 0.297996
# 	validation loss: 0.344563
# 	validation accuracy: 0.879
# Epoch 7 of 30 took 9.591s
# 	  training loss: 0.285537
# 	validation loss: 0.318870
# 	validation accuracy: 0.885
# Epoch 8 of 30 took 9.507s
# 	  training loss: 0.274556
# 	validation loss: 0.344550
# 	validation accuracy: 0.878
# Epoch 9 of 30 took 9.573s
# 	  training loss: 0.262425
# 	validation loss: 0.328421
# 	validation accuracy: 0.883
# Epoch 10 of 30 took 9.840s
# 	  training loss: 0.254398
# 	validation loss: 0.336238
# 	validation accuracy: 0.882
# Epoch 11 of 30 took 10.192s
# 	  training loss: 0.245614
# 	validation loss: 0.332525
# 	validation accuracy: 0.883
# Epoch 12 of 30 took 9.825s
# 	  training loss: 0.237499
# 	validation loss: 0.332105
# 	validation accuracy: 0.883
# Epoch 13 of 30 took 9.926s
# 	  training loss: 0.232602
# 	validation loss: 0.326658
# 	validation accuracy: 0.890
# Epoch 14 of 30 took 9.670s
# 	  training loss: 0.224290
# 	validation loss: 0.311530
# 	validation accuracy: 0.894
# Epoch 15 of 30 took 9.923s
# 	  training loss: 0.219144
# 	validation loss: 0.320319
# 	validation accuracy: 0.891
# Epoch 16 of 30 took 10.592s
# 	  training loss: 0.213595
# 	validation loss: 0.317962
# 	validation accuracy: 0.892
# Epoch 17 of 30 took 10.278s
# 	  training loss: 0.208977
# 	validation loss: 0.326222
# 	validation accuracy: 0.894
# Epoch 18 of 30 took 10.223s
# 	  training loss: 0.199340
# 	validation loss: 0.328960
# 	validation accuracy: 0.895
# Epoch 19 of 30 took 10.549s
# 	  training loss: 0.201816
# 	validation loss: 0.340314
# 	validation accuracy: 0.892
# Epoch 20 of 30 took 10.882s
# 	  training loss: 0.193733
# 	validation loss: 0.328967
# 	validation accuracy: 0.894
# Epoch 21 of 30 took 10.741s
# 	  training loss: 0.190698
# 	validation loss: 0.328715
# 	validation accuracy: 0.893
# Epoch 22 of 30 took 11.781s
# 	  training loss: 0.184694
# 	validation loss: 0.323908
# 	validation accuracy: 0.897
# Epoch 23 of 30 took 10.887s
# 	  training loss: 0.181489
# 	validation loss: 0.353917
# 	validation accuracy: 0.889
# Epoch 24 of 30 took 11.402s
# 	  training loss: 0.174732
# 	validation loss: 0.326935
# 	validation accuracy: 0.901
# Epoch 25 of 30 took 10.914s
# 	  training loss: 0.172525
# 	validation loss: 0.368138
# 	validation accuracy: 0.891
# Epoch 26 of 30 took 10.616s
# 	  training loss: 0.170717
# 	validation loss: 0.344279
# 	validation accuracy: 0.892
# Epoch 27 of 30 took 10.450s
# 	  training loss: 0.164639
# 	validation loss: 0.349395
# 	validation accuracy: 0.896
# Epoch 28 of 30 took 10.133s
# 	  training loss: 0.164186
# 	validation loss: 0.346052
# 	validation accuracy: 0.893
# Epoch 29 of 30 took 10.451s
# 	  training loss: 0.160534
# 	validation loss: 0.355010
# 	validation accuracy: 0.893
# Epoch 30 of 30 took 10.226s
# 	  training loss: 0.154882
# 	validation loss: 0.351252
# 	validation accuracy: 0.896

# %%
def plot_train_process(train_loss, val_loss, val_accuracy):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    axes[0].set_title('Loss')
    axes[0].plot(train_loss, label='train')
    axes[0].plot(val_loss, label='validation')
    axes[0].legend()

    axes[1].set_title('Validation accuracy')
    axes[1].plot(val_accuracy)

# %%
plot_train_process(train_loss, val_loss, val_accuracy)

# %% [markdown]
# **Вывод:** мы достигли требуемой оценки 0.885.

# %% [markdown]
# ### Task 2: Overfit it.
# Build a network that will overfit to this dataset. Demonstrate the overfitting in the appropriate way (e.g. plot loss and accurasy on train and test set w.r.t. network complexity).
#
# *Note:* you also might decrease the size of `train` dataset to enforce the overfitting and speed up the computations.

# %% [markdown]
# Для того чтобы добиться переобучение сделаем много больших слоев

# %%
print(len(train_loader))

print(len(test_loader))
# Out:
# 469
# 40

# %%
class OverfittingNeuralNetwork(nn.Module):
    def __init__(self, input_shape = 28 * 28, num_classes = 10, input_channels = 1):
        
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, 1000),
            nn.Tanh(),
            nn.Linear(1000, 500),
            nn.Tanh(),
            nn.Linear(500, num_classes)
        )
        
    def forward(self, inp):       
        out = self.model(inp)
        return out

# %%
torchsummary.summary(OverfittingNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                 [-1, 1000]         785,000
#               Tanh-3                 [-1, 1000]               0
#             Linear-4                  [-1, 500]         500,500
#               Tanh-5                  [-1, 500]               0
#             Linear-6                   [-1, 10]           5,010
# ================================================================
# Total params: 1,290,510
# Trainable params: 1,290,510
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 4.92
# Estimated Total Size (MB): 4.95
# ----------------------------------------------------------------

# %%
model = OverfittingNeuralNetwork().to(device)
opt = Adam(model.parameters(), lr=1e-3)
loss_func = nn.CrossEntropyLoss()

n_epochs = 50

train_loss, val_loss, val_accuracy = train_model(model, 
                                                 train_loader, 
                                                 test_loader, 
                                                 loss_func, 
                                                 opt, 
                                                 n_epochs)
# Out:
# Epoch 1 of 50 took 11.219s
# 	  training loss: 0.492330
# 	validation loss: 0.440557
# 	validation accuracy: 0.835
# Epoch 2 of 50 took 12.295s
# 	  training loss: 0.375813
# 	validation loss: 0.397073
# 	validation accuracy: 0.851
# Epoch 3 of 50 took 11.518s
# 	  training loss: 0.338800
# 	validation loss: 0.354901
# 	validation accuracy: 0.870
# Epoch 4 of 50 took 11.669s
# 	  training loss: 0.317113
# 	validation loss: 0.376659
# 	validation accuracy: 0.862
# Epoch 5 of 50 took 12.368s
# 	  training loss: 0.298916
# 	validation loss: 0.375214
# 	validation accuracy: 0.861
# Epoch 6 of 50 took 11.677s
# 	  training loss: 0.282933
# 	validation loss: 0.341211
# 	validation accuracy: 0.872
# Epoch 7 of 50 took 12.025s
# 	  training loss: 0.271216
# 	validation loss: 0.341111
# 	validation accuracy: 0.879
# Epoch 8 of 50 took 11.896s
# 	  training loss: 0.265097
# 	validation loss: 0.337140
# 	validation accuracy: 0.875
# Epoch 9 of 50 took 12.901s
# 	  training loss: 0.252837
# 	validation loss: 0.325094
# 	validation accuracy: 0.880
# Epoch 10 of 50 took 12.117s
# 	  training loss: 0.246437
# 	validation loss: 0.327171
# 	validation accuracy: 0.881
# Epoch 11 of 50 took 12.377s
# 	  training loss: 0.239620
# 	validation loss: 0.337206
# 	validation accuracy: 0.879
# Epoch 12 of 50 took 12.714s
# 	  training loss: 0.233853
# 	validation loss: 0.325125
# 	validation accuracy: 0.883
# Epoch 13 of 50 took 11.877s
# 	  training loss: 0.229320
# 	validation loss: 0.329031
# 	validation accuracy: 0.883
# Epoch 14 of 50 took 13.409s
# 	  training loss: 0.218974
# 	validation loss: 0.333709
# 	validation accuracy: 0.881
# Epoch 15 of 50 took 12.042s
# 	  training loss: 0.214782
# 	validation loss: 0.336510
# 	validation accuracy: 0.882
# Epoch 16 of 50 took 13.046s
# 	  training loss: 0.208868
# 	validation loss: 0.340404
# 	validation accuracy: 0.884
# Epoch 17 of 50 took 12.651s
# 	  training loss: 0.204591
# 	validation loss: 0.322496
# 	validation accuracy: 0.883
# Epoch 18 of 50 took 13.918s
# 	  training loss: 0.202567
# 	validation loss: 0.383292
# 	validation accuracy: 0.869
# Epoch 19 of 50 took 13.072s
# 	  training loss: 0.197283
# 	validation loss: 0.324718
# 	validation accuracy: 0.890
# Epoch 20 of 50 took 12.519s
# 	  training loss: 0.194050
# 	validation loss: 0.355967
# 	validation accuracy: 0.880
# Epoch 21 of 50 took 11.750s
# 	  training loss: 0.191125
# 	validation loss: 0.338931
# 	validation accuracy: 0.888
# Epoch 22 of 50 took 12.376s
# 	  training loss: 0.186620
# 	validation loss: 0.332768
# 	validation accuracy: 0.888
# Epoch 23 of 50 took 11.746s
# 	  training loss: 0.188518
# 	validation loss: 0.345323
# 	validation accuracy: 0.890
# Epoch 24 of 50 took 12.065s
# 	  training loss: 0.177315
# 	validation loss: 0.329994
# 	validation accuracy: 0.891
# Epoch 25 of 50 took 11.936s
# 	  training loss: 0.178302
# 	validation loss: 0.334282
# 	validation accuracy: 0.886
# Epoch 26 of 50 took 13.273s
# 	  training loss: 0.174312
# 	validation loss: 0.340539
# 	validation accuracy: 0.884
# Epoch 27 of 50 took 11.887s
# 	  training loss: 0.175219
# 	validation loss: 0.366694
# 	validation accuracy: 0.876
# Epoch 28 of 50 took 13.796s
# 	  training loss: 0.167302
# 	validation loss: 0.354825
# 	validation accuracy: 0.882
# Epoch 29 of 50 took 15.392s
# 	  training loss: 0.163561
# 	validation loss: 0.351328
# 	validation accuracy: 0.887
# Epoch 30 of 50 took 12.860s
# 	  training loss: 0.161105
# 	validation loss: 0.353823
# 	validation accuracy: 0.887
# Epoch 31 of 50 took 12.842s
# 	  training loss: 0.164840
# 	validation loss: 0.347941
# 	validation accuracy: 0.887
# Epoch 32 of 50 took 12.243s
# 	  training loss: 0.162581
# 	validation loss: 0.386962
# 	validation accuracy: 0.882
# Epoch 33 of 50 took 12.465s
# 	  training loss: 0.159002
# 	validation loss: 0.336029
# 	validation accuracy: 0.892
# Epoch 34 of 50 took 13.522s
# 	  training loss: 0.157221
# 	validation loss: 0.358874
# 	validation accuracy: 0.885
# Epoch 35 of 50 took 14.007s
# 	  training loss: 0.158430
# 	validation loss: 0.343685
# 	validation accuracy: 0.892
# Epoch 36 of 50 took 14.871s
# 	  training loss: 0.151400
# 	validation loss: 0.355221
# 	validation accuracy: 0.888
# Epoch 37 of 50 took 13.455s
# 	  training loss: 0.154615
# 	validation loss: 0.366368
# 	validation accuracy: 0.883
# Epoch 38 of 50 took 12.912s
# 	  training loss: 0.156470
# 	validation loss: 0.357725
# 	validation accuracy: 0.891
# Epoch 39 of 50 took 12.846s
# 	  training loss: 0.146814
# 	validation loss: 0.351510
# 	validation accuracy: 0.895
# Epoch 40 of 50 took 12.295s
# 	  training loss: 0.148923
# 	validation loss: 0.356805
# 	validation accuracy: 0.891
# Epoch 41 of 50 took 12.671s
# 	  training loss: 0.148792
# 	validation loss: 0.407707
# 	validation accuracy: 0.873
# Epoch 42 of 50 took 12.062s
# 	  training loss: 0.147220
# 	validation loss: 0.364373
# 	validation accuracy: 0.889
# Epoch 43 of 50 took 12.891s
# 	  training loss: 0.147508
# 	validation loss: 0.362439
# 	validation accuracy: 0.888
# Epoch 44 of 50 took 12.445s
# 	  training loss: 0.146754
# 	validation loss: 0.361258
# 	validation accuracy: 0.892
# Epoch 45 of 50 took 12.767s
# 	  training loss: 0.145412
# 	validation loss: 0.355077
# 	validation accuracy: 0.893
# Epoch 46 of 50 took 12.070s
# 	  training loss: 0.141662
# 	validation loss: 0.367990
# 	validation accuracy: 0.890
# Epoch 47 of 50 took 12.292s
# 	  training loss: 0.139205
# 	validation loss: 0.434888
# 	validation accuracy: 0.875
# Epoch 48 of 50 took 12.340s
# 	  training loss: 0.138298
# 	validation loss: 0.374590
# 	validation accuracy: 0.890
# Epoch 49 of 50 took 12.785s
# 	  training loss: 0.137347
# 	validation loss: 0.369609
# 	validation accuracy: 0.889
# Epoch 50 of 50 took 12.400s
# 	  training loss: 0.134965
# 	validation loss: 0.378198
# 	validation accuracy: 0.890

# %%
plot_train_process(train_loss, val_loss, val_accuracy)

# %% [markdown]
# ### Task 3: Fix it.
# Fix the overfitted network from the previous step (at least partially) by using regularization techniques (Dropout/Batchnorm/...) and demonstrate the results.

# %%
class FixedNeuralNetwork(nn.Module):
    def __init__(self, input_shape = 28 * 28, num_classes = 10, input_channels = 1):
        
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(input_shape, 1000),
            nn.Tanh(),
            nn.Dropout(p = .40, inplace= False),
            nn.Linear(1000, 500),
            nn.Tanh(),
            nn.BatchNorm1d(500, eps=3e-5),
            nn.Linear(500, num_classes)
        )
        
    def forward(self, inp):       
        out = self.model(inp)
        return out

# %%
torchsummary.summary(FixedNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                 [-1, 1000]         785,000
#               Tanh-3                 [-1, 1000]               0
#            Dropout-4                 [-1, 1000]               0
#             Linear-5                  [-1, 500]         500,500
#               Tanh-6                  [-1, 500]               0
#        BatchNorm1d-7                  [-1, 500]           1,000
#             Linear-8                   [-1, 10]           5,010
# ================================================================
# Total params: 1,291,510
# Trainable params: 1,291,510
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.04
# Params size (MB): 4.93
# Estimated Total Size (MB): 4.97
# ----------------------------------------------------------------

# %%
model = FixedNeuralNetwork().to(device)
opt = Adam(model.parameters(), lr=1e-3)
loss_func = nn.CrossEntropyLoss()

n_epochs = 50

train_loss, val_loss, val_accuracy = train_model(model, 
                                                 train_loader, 
                                                 test_loader, 
                                                 loss_func, 
                                                 opt, 
                                                 n_epochs)
# Out:
# Epoch 1 of 50 took 14.840s
# 	  training loss: 0.498991
# 	validation loss: 0.441797
# 	validation accuracy: 0.840
# Epoch 2 of 50 took 14.664s
# 	  training loss: 0.404484
# 	validation loss: 0.393085
# 	validation accuracy: 0.858
# Epoch 3 of 50 took 15.092s
# 	  training loss: 0.371372
# 	validation loss: 0.380593
# 	validation accuracy: 0.862
# Epoch 4 of 50 took 15.373s
# 	  training loss: 0.351693
# 	validation loss: 0.425136
# 	validation accuracy: 0.839
# Epoch 5 of 50 took 15.295s
# 	  training loss: 0.334349
# 	validation loss: 0.383474
# 	validation accuracy: 0.862
# Epoch 6 of 50 took 15.383s
# 	  training loss: 0.321437
# 	validation loss: 0.356672
# 	validation accuracy: 0.871
# Epoch 7 of 50 took 16.306s
# 	  training loss: 0.315532
# 	validation loss: 0.363186
# 	validation accuracy: 0.869
# Epoch 8 of 50 took 15.718s
# 	  training loss: 0.306885
# 	validation loss: 0.344977
# 	validation accuracy: 0.873
# Epoch 9 of 50 took 15.403s
# 	  training loss: 0.305373
# 	validation loss: 0.338219
# 	validation accuracy: 0.877
# Epoch 10 of 50 took 15.327s
# 	  training loss: 0.297150
# 	validation loss: 0.364620
# 	validation accuracy: 0.869
# Epoch 11 of 50 took 15.227s
# 	  training loss: 0.294609
# 	validation loss: 0.343081
# 	validation accuracy: 0.870
# Epoch 12 of 50 took 15.251s
# 	  training loss: 0.290335
# 	validation loss: 0.332512
# 	validation accuracy: 0.880
# Epoch 13 of 50 took 15.541s
# 	  training loss: 0.285633
# 	validation loss: 0.341813
# 	validation accuracy: 0.878
# Epoch 14 of 50 took 15.111s
# 	  training loss: 0.280263
# 	validation loss: 0.337173
# 	validation accuracy: 0.879
# Epoch 15 of 50 took 15.431s
# 	  training loss: 0.278470
# 	validation loss: 0.337543
# 	validation accuracy: 0.878
# Epoch 16 of 50 took 15.188s
# 	  training loss: 0.277018
# 	validation loss: 0.352606
# 	validation accuracy: 0.876
# Epoch 17 of 50 took 15.102s
# 	  training loss: 0.274126
# 	validation loss: 0.352629
# 	validation accuracy: 0.875
# Epoch 18 of 50 took 15.332s
# 	  training loss: 0.273518
# 	validation loss: 0.342876
# 	validation accuracy: 0.875
# Epoch 19 of 50 took 15.273s
# 	  training loss: 0.272715
# 	validation loss: 0.335917
# 	validation accuracy: 0.882
# Epoch 20 of 50 took 15.090s
# 	  training loss: 0.266679
# 	validation loss: 0.330652
# 	validation accuracy: 0.882
# Epoch 21 of 50 took 15.218s
# 	  training loss: 0.266142
# 	validation loss: 0.333075
# 	validation accuracy: 0.879
# Epoch 22 of 50 took 15.350s
# 	  training loss: 0.263289
# 	validation loss: 0.336695
# 	validation accuracy: 0.879
# Epoch 23 of 50 took 14.878s
# 	  training loss: 0.265147
# 	validation loss: 0.331791
# 	validation accuracy: 0.881
# Epoch 24 of 50 took 15.123s
# 	  training loss: 0.263893
# 	validation loss: 0.317377
# 	validation accuracy: 0.888
# Epoch 25 of 50 took 14.850s
# 	  training loss: 0.255950
# 	validation loss: 0.327968
# 	validation accuracy: 0.882
# Epoch 26 of 50 took 15.282s
# 	  training loss: 0.257982
# 	validation loss: 0.330649
# 	validation accuracy: 0.884
# Epoch 27 of 50 took 15.237s
# 	  training loss: 0.252814
# 	validation loss: 0.330596
# 	validation accuracy: 0.885
# Epoch 28 of 50 took 14.924s
# 	  training loss: 0.254093
# 	validation loss: 0.332578
# 	validation accuracy: 0.887
# Epoch 29 of 50 took 15.158s
# 	  training loss: 0.253539
# 	validation loss: 0.330970
# 	validation accuracy: 0.884
# Epoch 30 of 50 took 14.940s
# 	  training loss: 0.252109
# 	validation loss: 0.333456
# 	validation accuracy: 0.884
# Epoch 31 of 50 took 15.193s
# 	  training loss: 0.250451
# 	validation loss: 0.333800
# 	validation accuracy: 0.880
# Epoch 32 of 50 took 14.899s
# 	  training loss: 0.244542
# 	validation loss: 0.318747
# 	validation accuracy: 0.887
# Epoch 33 of 50 took 15.151s
# 	  training loss: 0.245260
# 	validation loss: 0.322226
# 	validation accuracy: 0.890
# Epoch 34 of 50 took 15.333s
# 	  training loss: 0.245466
# 	validation loss: 0.328036
# 	validation accuracy: 0.887
# Epoch 35 of 50 took 14.916s
# 	  training loss: 0.243513
# 	validation loss: 0.326749
# 	validation accuracy: 0.890
# Epoch 36 of 50 took 15.270s
# 	  training loss: 0.242245
# 	validation loss: 0.327595
# 	validation accuracy: 0.887
# Epoch 37 of 50 took 15.064s
# 	  training loss: 0.244961
# 	validation loss: 0.326469
# 	validation accuracy: 0.885
# Epoch 38 of 50 took 16.947s
# 	  training loss: 0.238825
# 	validation loss: 0.322422
# 	validation accuracy: 0.894
# Epoch 39 of 50 took 18.281s
# 	  training loss: 0.243265
# 	validation loss: 0.319554
# 	validation accuracy: 0.889
# Epoch 40 of 50 took 16.431s
# 	  training loss: 0.240568
# 	validation loss: 0.325614
# 	validation accuracy: 0.886
# Epoch 41 of 50 took 17.598s
# 	  training loss: 0.243089
# 	validation loss: 0.316787
# 	validation accuracy: 0.891
# Epoch 42 of 50 took 16.428s
# 	  training loss: 0.237697
# 	validation loss: 0.332308
# 	validation accuracy: 0.885
# Epoch 43 of 50 took 15.802s
# 	  training loss: 0.236424
# 	validation loss: 0.311839
# 	validation accuracy: 0.891
# Epoch 44 of 50 took 15.801s
# 	  training loss: 0.233632
# 	validation loss: 0.324073
# 	validation accuracy: 0.886
# Epoch 45 of 50 took 17.090s
# 	  training loss: 0.233436
# 	validation loss: 0.324123
# 	validation accuracy: 0.887
# Epoch 46 of 50 took 16.006s
# 	  training loss: 0.235474
# 	validation loss: 0.327729
# 	validation accuracy: 0.883
# Epoch 47 of 50 took 16.010s
# 	  training loss: 0.232713
# 	validation loss: 0.320252
# 	validation accuracy: 0.889
# Epoch 48 of 50 took 15.042s
# 	  training loss: 0.231746
# 	validation loss: 0.328304
# 	validation accuracy: 0.886
# Epoch 49 of 50 took 15.434s
# 	  training loss: 0.232071
# 	validation loss: 0.315124
# 	validation accuracy: 0.895
# Epoch 50 of 50 took 15.764s
# 	  training loss: 0.229259
# 	validation loss: 0.331465
# 	validation accuracy: 0.886

# %%
plot_train_process(train_loss, val_loss, val_accuracy)

# %% [markdown]
# ### Conclusions:
# _Write down small report with your conclusions and your ideas._

# %% [markdown]
# При обучении нейронок очень легко переобучиться
#
# Для того чтобы избежать возможноог переобучения стоит использовать следующие методы:
# - Нормализировать данные (**nn.BatchNorm1d**).
# - Использовать **Dropout**.
# - Использовать _правильный_ оптимайзер.
# - Выбирать правильную стратегию кросс-валидации.
# - Контролировать количество слоев и их размер.
#
# Для обучения нейронок очень полезно иметь GPU.
