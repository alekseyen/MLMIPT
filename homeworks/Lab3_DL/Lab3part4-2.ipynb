# %% [markdown]
# ## Lab 3: final challenges
#
# __Вам предлагается решить задачу классификации сигналов (вы уже встречались с ней во второй лабораторной работе) или задачу классификации изображений. Или обе ;)__
#
# __Выполнение этих заданий не является обязательным, но позитивно повлияет на вашу итоговую оценку. Успехов!__

# %% [markdown]
# ### Part 4. HAR classification with raw data (2+ points)
# __Disclaimer__: Это опциональная часть задания. Здесь придется экспериментировать, подбирать оптимальную структуру сети для решения задачи и активно искать подскзаки в сети.
#
#
# Данное задание составлено на основе данного [поста](https://burakhimmetoglu.com/2017/08/22/time-series-classification-with-tensorflow/). С помощью вручную сгенерированных фичей и классических подходов задача распознования движений была решена с точностью 96%.
#
# Также будет полезным изучить [вот этот](https://github.com/healthDataScience/deep-learning-HAR), а так же [вот этот репозиторий](https://github.com/guillaume-chevalier/LSTM-Human-Activity-Recognition), где к данной задаче рассматривается несколько подходов.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import pylab
import warnings as w
import os
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score
from itertools import cycle

# %matplotlib inline
# Out:
# UsageError: unrecognized arguments: numpy as np

# %%
import matplotlib
matplotlib.rcParams.update({'font.size':14})

# %% [markdown]
# Вернемся к задаче классификации движений на основе [данных](https://archive.ics.uci.edu/ml/datasets/Human+Activity+Recognition+Using+Smartphones) из репозитория UCI ([прямая ссылка на скачивание](https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip)).
#
# В этот раз будем работать с исходными, а не предобработанными данными. Данные представляют собой сигналы с гироскопа и акселерометра, закрепленного на теле человека. Каждому семплу соотвествует 9 связанных временных рядов.

# %% [markdown]
# В начале приведена визуализация данных на основе PCA над вручную сгенерированными признаками. Для отрисовки графиков (цвет и легенда) нам также понадобятся метки классов.

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# !unzip UCI\ HAR\ Dataset.zip
# Out:
# --2020-06-08 08:13:17--  https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60999314 (58M) [application/x-httpd-php]
# Saving to: ‘UCI HAR Dataset.zip.1’
#
# UCI HAR Dataset.zip 100%[===================>]  58.17M  17.1MB/s    in 4.3s
#
# 2020-06-08 08:13:22 (13.4 MB/s) - ‘UCI HAR Dataset.zip.1’ saved [60999314/60999314]
#
# Archive:  UCI HAR Dataset.zip
# replace UCI HAR Dataset/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace __MACOSX/UCI HAR Dataset/._.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: no
# replace UCI HAR Dataset/activity_labels.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
X_train_with_engineered_features = np.genfromtxt(os.path.join("UCI HAR Dataset", "train", "X_train.txt"))
y_train = np.genfromtxt(os.path.join("UCI HAR Dataset", "train", "y_train.txt"))

y_train_list = list(y_train)
X_unique = np.array([X_train_with_engineered_features[y_train_list.index(l)]
                             for l in sorted(list(set(y_train)))])

legend_labels = ["WALKING", "WALKING.UP", "WALKING.DOWN", "SITTING", "STANDING", "LAYING"]
colors_list = ['red', 'blue', 'green', 'orange', 'cyan', 'magenta']
mapped_colors = [colors_list[int(i)-1] for i in y_train]

from sklearn.decomposition import PCA
pca = PCA()

X_train_pca = pca.fit_transform(X_train_with_engineered_features)

plt.figure(figsize=(15,10))
pylab.scatter(X_train_pca[:, 0], X_train_pca[:, 1],
             c=mapped_colors)
plt.grid()
for idx, x in enumerate(pca.transform(X_unique)):
    plt.scatter(x[0], 
                x[1], 
                c=colors_list[idx], 
                label=legend_labels[idx])
plt.xlabel('First principal component')
plt.ylabel('Second principal component')
plt.legend()

# %%
# Useful Constants

# Those are separate normalised input features for the neural network
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_"
]

# Output classes to learn how to classify
LABELS = [
    "WALKING", 
    "WALKING_UPSTAIRS", 
    "WALKING_DOWNSTAIRS", 
    "SITTING", 
    "STANDING", 
    "LAYING"
]

DATA_PATH = "./"

DATASET_PATH = DATA_PATH + "UCI HAR Dataset/"
print("\n" + "Dataset is now located at: " + DATASET_PATH)

TRAIN = "train/"
TEST = "test/"


# Load "X" (the neural network's training and testing inputs)

def load_X(X_signals_paths):
    X_signals = []
    
    for signal_type_path in X_signals_paths:
        file = open(signal_type_path, 'r')
        # Read dataset from disk, dealing with text files' syntax
        X_signals.append(
            [np.array(serie, dtype=np.float32) for serie in [
                row.replace('  ', ' ').strip().split(' ') for row in file
            ]]
        )
        file.close()
    
    return np.transpose(np.array(X_signals), (1, 2, 0))

X_train_signals_paths = [
    os.path.join(*[DATASET_PATH, TRAIN, "Inertial Signals/", signal+"train.txt"]) for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    os.path.join(*[DATASET_PATH, TEST, "Inertial Signals/", signal+"test.txt"]) for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)


# Load "y" (the neural network's training and testing outputs)

def load_y(y_path):
    file = open(y_path, 'r')
    # Read dataset from disk, dealing with text file's syntax
    y_ = np.array(
        [elem for elem in [
            row.replace('  ', ' ').strip().split(' ') for row in file
        ]], 
        dtype=np.int32
    )
    file.close()
    
    # Substract 1 to each output class for friendly 0-based indexing 
    return y_ - 1

y_train_path = os.path.join(DATASET_PATH, TRAIN, "y_train.txt")
y_test_path = os.path.join(DATASET_PATH, TEST, "y_test.txt")

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)
# Out:
# Dataset is now located at: ./UCI HAR Dataset/

# %%
# Input Data 

training_data_count = len(X_train)  # 7352 training series (with 50% overlap between each serie)
test_data_count = len(X_test)  # 2947 testing series
n_steps = len(X_train[0])  # 128 timesteps per series
n_input = len(X_train[0][0])  # 9 input parameters per timestep


# LSTM Neural Network's internal structure

n_hidden = 32 # Hidden layer num of features
n_classes = 6 # Total classes (should go up, or should go down)


# Some debugging info

print("Some useful info to get an insight on dataset's shape and normalisation:")
print("(X shape, y shape, every X's mean, every X's standard deviation)")
print(X_test.shape, y_test.shape, np.mean(X_test), np.std(X_test))
print("The dataset is therefore properly normalised, as expected, but not yet one-hot encoded.")
# Out:
# Some useful info to get an insight on dataset's shape and normalisation:
# (X shape, y shape, every X's mean, every X's standard deviation)
# (2947, 128, 9) (2947, 1) 0.09913992 0.39567086
# The dataset is therefore properly normalised, as expected, but not yet one-hot encoded.

# %% [markdown]
# #### Построение сети и эксперименты. (100% +)
#
# __Ваша задача - построить сеть, которая решит задачу классификации с точностью (`accuracy`) не менее 86%.__
# Разбалловка следующая:
# * $=$86% - 2 points
# * $>=$89% - 2.5 points
# * $>=$91% - 3 points
#
#
# __Warning!__ В сети существует несколько решений данной задачи с использованием различных фреймворков. При проверке это будет учитываться, так что свое решение нужно будет объяснить. Пожалуйста, не копируйте бездумно код, такие задания будут оценены 0 баллов. Если задача не решается - можете обратиться к заданию по классификации изображений.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical
from keras.utils import np_utils

# %%
X_train = X_train.reshape(X_train.shape[0], 1, 32, -1)
y_train = y_train.reshape(-1)

Y_train = np_utils.to_categorical(y_train, 6)

# %%
X_test = X_test.reshape(X_test.shape[0], 1, 32, -1)
y_test = y_test.reshape(-1)
Y_test = np_utils.to_categorical(y_test, 6)

# %%
model = Sequential()
 
model.add(Convolution2D(32, (3, 3), activation='relu', input_shape=(1,32,36), data_format='channels_first'))
model.add(MaxPooling2D(pool_size=(3,3)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(BatchNormalization())
model.add(Dense(6, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# %%time
history = model.fit(X_train, Y_train, epochs=100, validation_split=0.1, batch_size=256, shuffle=True)
# Out:
# Epoch 1/100
# 26/26 [==============================] - 0s 15ms/step - loss: 0.6675 - accuracy: 0.7296 - val_loss: 0.9406 - val_accuracy: 0.6685
# Epoch 2/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.2900 - accuracy: 0.8969 - val_loss: 0.4919 - val_accuracy: 0.8451
# Epoch 3/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1951 - accuracy: 0.9306 - val_loss: 0.3676 - val_accuracy: 0.9158
# Epoch 4/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1630 - accuracy: 0.9421 - val_loss: 0.3236 - val_accuracy: 0.9198
# Epoch 5/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1448 - accuracy: 0.9472 - val_loss: 0.2833 - val_accuracy: 0.9103
# Epoch 6/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1337 - accuracy: 0.9506 - val_loss: 0.2246 - val_accuracy: 0.9198
# Epoch 7/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1281 - accuracy: 0.9521 - val_loss: 0.2036 - val_accuracy: 0.9361
# Epoch 8/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1179 - accuracy: 0.9574 - val_loss: 0.2159 - val_accuracy: 0.9076
# Epoch 9/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1157 - accuracy: 0.9586 - val_loss: 0.1867 - val_accuracy: 0.9334
# Epoch 10/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1076 - accuracy: 0.9599 - val_loss: 0.1637 - val_accuracy: 0.9253
# Epoch 11/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.1063 - accuracy: 0.9592 - val_loss: 0.1377 - val_accuracy: 0.9416
# Epoch 12/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1072 - accuracy: 0.9609 - val_loss: 0.1345 - val_accuracy: 0.9402
# Epoch 13/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0985 - accuracy: 0.9602 - val_loss: 0.1638 - val_accuracy: 0.9307
# Epoch 14/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.1013 - accuracy: 0.9604 - val_loss: 0.1620 - val_accuracy: 0.9348
# Epoch 15/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0986 - accuracy: 0.9606 - val_loss: 0.1894 - val_accuracy: 0.9293
# Epoch 16/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0983 - accuracy: 0.9599 - val_loss: 0.0990 - val_accuracy: 0.9497
# Epoch 17/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0972 - accuracy: 0.9584 - val_loss: 0.1718 - val_accuracy: 0.9307
# Epoch 18/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0930 - accuracy: 0.9621 - val_loss: 0.2293 - val_accuracy: 0.8927
# Epoch 19/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0881 - accuracy: 0.9642 - val_loss: 0.1223 - val_accuracy: 0.9361
# Epoch 20/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0894 - accuracy: 0.9646 - val_loss: 0.1249 - val_accuracy: 0.9212
# Epoch 21/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0874 - accuracy: 0.9640 - val_loss: 0.1385 - val_accuracy: 0.9402
# Epoch 22/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0842 - accuracy: 0.9634 - val_loss: 0.1376 - val_accuracy: 0.9198
# Epoch 23/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0826 - accuracy: 0.9666 - val_loss: 0.1489 - val_accuracy: 0.9361
# Epoch 24/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0808 - accuracy: 0.9658 - val_loss: 0.1605 - val_accuracy: 0.9321
# Epoch 25/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0806 - accuracy: 0.9667 - val_loss: 0.2001 - val_accuracy: 0.9266
# Epoch 26/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0796 - accuracy: 0.9669 - val_loss: 0.1618 - val_accuracy: 0.9375
# Epoch 27/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0791 - accuracy: 0.9666 - val_loss: 0.1374 - val_accuracy: 0.9402
# Epoch 28/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0769 - accuracy: 0.9698 - val_loss: 0.1981 - val_accuracy: 0.9307
# Epoch 29/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0765 - accuracy: 0.9681 - val_loss: 0.0744 - val_accuracy: 0.9701
# Epoch 30/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0743 - accuracy: 0.9683 - val_loss: 0.1070 - val_accuracy: 0.9484
# Epoch 31/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0723 - accuracy: 0.9692 - val_loss: 0.1460 - val_accuracy: 0.9348
# Epoch 32/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0692 - accuracy: 0.9696 - val_loss: 0.1072 - val_accuracy: 0.9484
# Epoch 33/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0682 - accuracy: 0.9711 - val_loss: 0.1801 - val_accuracy: 0.9361
# Epoch 34/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0715 - accuracy: 0.9690 - val_loss: 0.1237 - val_accuracy: 0.9470
# Epoch 35/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0667 - accuracy: 0.9704 - val_loss: 0.1310 - val_accuracy: 0.9361
# Epoch 36/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0631 - accuracy: 0.9716 - val_loss: 0.1250 - val_accuracy: 0.9470
# Epoch 37/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0654 - accuracy: 0.9711 - val_loss: 0.0720 - val_accuracy: 0.9715
# Epoch 38/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0626 - accuracy: 0.9716 - val_loss: 0.0820 - val_accuracy: 0.9579
# Epoch 39/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0622 - accuracy: 0.9729 - val_loss: 0.0746 - val_accuracy: 0.9742
# Epoch 40/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0618 - accuracy: 0.9745 - val_loss: 0.1382 - val_accuracy: 0.9389
# Epoch 41/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0587 - accuracy: 0.9764 - val_loss: 0.1569 - val_accuracy: 0.9389
# Epoch 42/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0541 - accuracy: 0.9781 - val_loss: 0.0899 - val_accuracy: 0.9592
# Epoch 43/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0572 - accuracy: 0.9764 - val_loss: 0.0508 - val_accuracy: 0.9783
# Epoch 44/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0604 - accuracy: 0.9746 - val_loss: 0.0877 - val_accuracy: 0.9660
# Epoch 45/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0568 - accuracy: 0.9758 - val_loss: 0.0966 - val_accuracy: 0.9552
# Epoch 46/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0559 - accuracy: 0.9761 - val_loss: 0.1254 - val_accuracy: 0.9484
# Epoch 47/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0523 - accuracy: 0.9782 - val_loss: 0.1127 - val_accuracy: 0.9538
# Epoch 48/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0523 - accuracy: 0.9781 - val_loss: 0.0805 - val_accuracy: 0.9633
# Epoch 49/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0525 - accuracy: 0.9802 - val_loss: 0.0726 - val_accuracy: 0.9592
# Epoch 50/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0493 - accuracy: 0.9790 - val_loss: 0.0728 - val_accuracy: 0.9701
# Epoch 51/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0556 - accuracy: 0.9766 - val_loss: 0.0705 - val_accuracy: 0.9742
# Epoch 52/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0501 - accuracy: 0.9797 - val_loss: 0.1414 - val_accuracy: 0.9389
# Epoch 53/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0471 - accuracy: 0.9823 - val_loss: 0.1377 - val_accuracy: 0.9429
# Epoch 54/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0483 - accuracy: 0.9807 - val_loss: 0.0804 - val_accuracy: 0.9606
# Epoch 55/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0441 - accuracy: 0.9829 - val_loss: 0.0596 - val_accuracy: 0.9755
# Epoch 56/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0429 - accuracy: 0.9820 - val_loss: 0.1358 - val_accuracy: 0.9457
# Epoch 57/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0406 - accuracy: 0.9838 - val_loss: 0.0479 - val_accuracy: 0.9837
# Epoch 58/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0436 - accuracy: 0.9820 - val_loss: 0.0529 - val_accuracy: 0.9810
# Epoch 59/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0468 - accuracy: 0.9808 - val_loss: 0.0514 - val_accuracy: 0.9728
# Epoch 60/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0471 - accuracy: 0.9814 - val_loss: 0.1060 - val_accuracy: 0.9416
# Epoch 61/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0427 - accuracy: 0.9834 - val_loss: 0.0444 - val_accuracy: 0.9837
# Epoch 62/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0379 - accuracy: 0.9850 - val_loss: 0.0410 - val_accuracy: 0.9864
# Epoch 63/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0411 - accuracy: 0.9826 - val_loss: 0.0659 - val_accuracy: 0.9769
# Epoch 64/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0374 - accuracy: 0.9849 - val_loss: 0.0515 - val_accuracy: 0.9823
# Epoch 65/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0412 - accuracy: 0.9832 - val_loss: 0.0615 - val_accuracy: 0.9688
# Epoch 66/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0416 - accuracy: 0.9841 - val_loss: 0.0510 - val_accuracy: 0.9783
# Epoch 67/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0410 - accuracy: 0.9835 - val_loss: 0.1151 - val_accuracy: 0.9538
# Epoch 68/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0373 - accuracy: 0.9855 - val_loss: 0.0324 - val_accuracy: 0.9878
# Epoch 69/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0396 - accuracy: 0.9832 - val_loss: 0.0451 - val_accuracy: 0.9864
# Epoch 70/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0407 - accuracy: 0.9841 - val_loss: 0.0918 - val_accuracy: 0.9592
# Epoch 71/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0342 - accuracy: 0.9852 - val_loss: 0.0847 - val_accuracy: 0.9633
# Epoch 72/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0312 - accuracy: 0.9894 - val_loss: 0.0401 - val_accuracy: 0.9851
# Epoch 73/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0339 - accuracy: 0.9865 - val_loss: 0.0370 - val_accuracy: 0.9823
# Epoch 74/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0296 - accuracy: 0.9869 - val_loss: 0.0468 - val_accuracy: 0.9810
# Epoch 75/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0315 - accuracy: 0.9873 - val_loss: 0.0196 - val_accuracy: 0.9946
# Epoch 76/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0312 - accuracy: 0.9878 - val_loss: 0.1712 - val_accuracy: 0.9511
# Epoch 77/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0349 - accuracy: 0.9844 - val_loss: 0.0680 - val_accuracy: 0.9701
# Epoch 78/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0324 - accuracy: 0.9865 - val_loss: 0.0599 - val_accuracy: 0.9769
# Epoch 79/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0318 - accuracy: 0.9884 - val_loss: 0.0405 - val_accuracy: 0.9851
# Epoch 80/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0285 - accuracy: 0.9900 - val_loss: 0.0334 - val_accuracy: 0.9837
# Epoch 81/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0260 - accuracy: 0.9899 - val_loss: 0.1011 - val_accuracy: 0.9592
# Epoch 82/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0353 - accuracy: 0.9865 - val_loss: 0.0409 - val_accuracy: 0.9783
# Epoch 83/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0356 - accuracy: 0.9849 - val_loss: 0.0649 - val_accuracy: 0.9688
# Epoch 84/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0358 - accuracy: 0.9858 - val_loss: 0.1510 - val_accuracy: 0.9402
# Epoch 85/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0294 - accuracy: 0.9867 - val_loss: 0.0351 - val_accuracy: 0.9837
# Epoch 86/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0300 - accuracy: 0.9876 - val_loss: 0.0296 - val_accuracy: 0.9891
# Epoch 87/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0308 - accuracy: 0.9885 - val_loss: 0.0219 - val_accuracy: 0.9932
# Epoch 88/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0300 - accuracy: 0.9879 - val_loss: 0.0311 - val_accuracy: 0.9891
# Epoch 89/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0320 - accuracy: 0.9869 - val_loss: 0.0192 - val_accuracy: 0.9946
# Epoch 90/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0344 - accuracy: 0.9862 - val_loss: 0.0365 - val_accuracy: 0.9810
# Epoch 91/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0260 - accuracy: 0.9903 - val_loss: 0.0449 - val_accuracy: 0.9755
# Epoch 92/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0247 - accuracy: 0.9900 - val_loss: 0.1386 - val_accuracy: 0.9579
# Epoch 93/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0289 - accuracy: 0.9881 - val_loss: 0.0259 - val_accuracy: 0.9932
# Epoch 94/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0276 - accuracy: 0.9891 - val_loss: 0.0338 - val_accuracy: 0.9851
# Epoch 95/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0293 - accuracy: 0.9885 - val_loss: 0.0258 - val_accuracy: 0.9905
# Epoch 96/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0303 - accuracy: 0.9876 - val_loss: 0.0213 - val_accuracy: 0.9932
# Epoch 97/100
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0272 - accuracy: 0.9899 - val_loss: 0.0559 - val_accuracy: 0.9701
# Epoch 98/100
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0260 - accuracy: 0.9902 - val_loss: 0.0370 - val_accuracy: 0.9783
# Epoch 99/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0235 - accuracy: 0.9906 - val_loss: 0.0204 - val_accuracy: 0.9932
# Epoch 100/100
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0227 - accuracy: 0.9915 - val_loss: 0.0122 - val_accuracy: 0.9973
# CPU times: user 21.3 s, sys: 5.31 s, total: 26.6 s
# Wall time: 29.4 s

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, 101)
plt.plot(epochs, loss_values, label='Training loss')
plt.plot(epochs, val_loss_values, label='Validation loss')

plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.figure(figsize=(13,8))
plt.show()

# %%
predictions= model.predict(X_test)

# %%
y_pred = [np.argmax(x) for x in predictions]

# %%
y_test = y_test.reshape(-1)

# %%
(y_pred == y_test).mean()
# Out:
# 0.9314557176789956

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       496
#            1       0.96      0.92      0.94       471
#            2       0.89      0.96      0.92       420
#            3       0.96      0.79      0.87       491
#            4       0.85      0.97      0.91       532
#            5       0.99      1.00      1.00       537
#
#     accuracy                           0.93      2947
#    macro avg       0.93      0.93      0.93      2947
# weighted avg       0.94      0.93      0.93      2947

# %% [markdown]
# **Вывод:** попробоавли себя в tenserflow. Поигравшись со слоями достигли качества в ~0.93 на валидации
